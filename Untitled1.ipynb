# %%
import requests 
URL = "https://www.geeksforgeeks.org/data-structures/"
r = requests.get(URL) 
print(r.content)

# %%
import requests 
from bs4 import BeautifulSoup 
  
URL = "http://www.values.com/inspirational-quotes"
r = requests.get(URL) 
  
soup = BeautifulSoup(r.content, 'html5lib') 
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-US">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <link href="https://fonts.googleapis.com/css?family=Roboto:900|Lato:300,400,400italic,600,700|Raleway:300,400,500,600,700|Crete+Round:400italic|Zilla+Slab" rel="stylesheet" type="text/css"/>
#   <link href="/assets/application-f7c42ac1a26bc766307e42ff5df71b58.css" media="all" rel="stylesheet"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <!--[if lt IE 9]><script src="http://css3-mediaqueries-js.googlecode.com/svn/trunk/css3-mediaqueries.js"></script><![endif]-->
#   <title>
#    Inspirational Quotes - Motivational Quotes - Leadership Quotes | PassItOn.com
#   </title>
#   <meta content="Find the perfect quotation from our hand-picked collection of inspiring quotes by hundreds of authors." name="description"/>
#   <meta content="authenticity_token" name="csrf-param"/>
#   <meta content="bhMrxyJNsdF3o9qnHYQV4DvbFRruQ21mxa0cmqupX0Idr1DCDSpabEQH7/GaZ1LkLT44fMZfU4zbxB6csTIDtw==" name="csrf-token"/>
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#         (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#         m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#         })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#         ga('create', 'UA-1179606-29', 'auto');
#         ga('require', 'displayfeatures');
#         ga('send', 'pageview');
#   </script>
#   <script>
#    window.fbAsyncInit = function() {
#         FB.init({
#           appId      : '483774921971842',
#           cookie     : true,
#           xfbml      : true,
#           version    : '3.0'
#         });
#
#         FB.AppEvents.logPageView();
#
#       };
#
#       (function(d, s, id){
#          var js, fjs = d.getElementsByTagName(s)[0];
#          if (d.getElementById(id)) {return;}
#          js = d.createElement(s); js.id = id;
#          js.src = "https://connect.facebook.net/en_US/sdk.js";
#          fjs.parentNode.insertBefore(js, fjs);
#        }(document, 'script', 'facebook-jssdk'));
#   </script>
#   <meta content="passiton.com" property="og:site_name"/>
#   <meta content="Inspirational Quotes - Motivational Quotes - Leadership Quotes" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://www.passiton.com/passiton.jpg" property="og:image"/>
#   <meta content="https://www.passiton.com/inspirational-quotes" property="og:url"/>
#   <meta content="Find the perfect quotation from our hand-picked collection of inspiring quotes by hundreds of authors." property="og:description"/>
#   <meta content="483774921971842" property="fb:app_id"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@passiton" name="twitter:site"/>
#   <meta content="@passiton" name="twitter:creator"/>
#   <meta content="Inspirational Quotes - Motivational Quotes - Leadership Quotes" name="twitter:title"/>
#   <meta content="Find the perfect quotation from our hand-picked collection of inspiring quotes by hundreds of authors." name="twitter:description"/>
#   <meta content="https://www.passiton.com/passiton.jpg" name="twitter:image"/>
#   <meta content="https://www.passiton.com/inspirational-quotes" name="twitter:url"/>
#   <meta content="passiton.com" itemprop="name"/>
#   <meta content="Find the perfect quotation from our hand-picked collection of inspiring quotes by hundreds of authors." itemprop="description"/>
#   <meta content="https://www.passiton.com/passiton.jpg" itemprop="image"/>
#   <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link color="#C8102E" href="/passiton_arrow.svg" rel="mask-icon"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <link color="#5bbad5" href="/safari-pinned-tab.svg" rel="mask-icon"/>
#   <meta content="passiton" name="apple-mobile-web-app-title"/>
#   <meta content="passiton" name="application-name"/>
#   <meta content="#f1f1f1" name="theme-color"/>
#  </head>
#  <body class="stretched no-transition quotes_index">
#   <div class="clearfix" id="wrapper">
#    <header class="full-header dark" data-sticky-class="dark" id="header">
#     <div id="header-wrap">
#      <div class="container clearfix">
#       <div id="primary-menu-trigger">
#        <i class="icon-reorder">
#        </i>
#       </div>
#       <div id="logo">
#        <a class="standard-logo" data-dark-logo="/assets/logo-dark-7b51f8d9634d3b1a21937f284fa87e90.png" href="/">
#         <img alt="passiton.com" src="/assets/logo-7b51f8d9634d3b1a21937f284fa87e90.png"/>
#        </a>
#        <a class="retina-logo" data-dark-logo="/assets/logo-dark@2x-489985db9fac6d33cd09d160857bedd4.png" href="/">
#         <img alt="passiton.com" src="/assets/logo@2x-489985db9fac6d33cd09d160857bedd4.png"/>
#        </a>
#       </div>
#       <nav class="" id="primary-menu">
#        <ul>
#         <li class="current">
#          <a href="/inspirational-quotes">
#           quotes
#          </a>
#         </li>
#         <li class="">
#          <a href="/inspirational-stories-tv-spots">
#           videos
#          </a>
#         </li>
#         <li class="">
#          <a href="/inspirational-sayings-billboards">
#           <i class="icon-caret-down">
#           </i>
#           billboards
#          </a>
#          <ul>
#           <li class="">
#            <a href="/inspirational-sayings-billboards">
#             official billboards
#            </a>
#           </li>
#           <li class="">
#            <a href="/your-billboards/create">
#             create your own billboard
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="">
#          <a href="/radio">
#           radio ads
#          </a>
#         </li>
#         <li class="">
#          <a href="/who-we-are">
#           about us
#          </a>
#         </li>
#         <li class="">
#          <a href="/contact-us">
#           contact
#          </a>
#         </li>
#         <li class="">
#          <a class="dropdown-toggle" href="">
#           <i class="icon-caret-down">
#           </i>
#           language
#          </a>
#          <ul class="dark">
#           <li class="dark">
#            <a href="https://www.pasala.org/" target="_blank">
#             Español
#            </a>
#           </li>
#           <li class="dark">
#            <a href="https://www.umavidamelhor.org/" target="_blank">
#             Português
#            </a>
#           </li>
#           <li class="dark">
#            <a href="https://values.cn.com/" target="_blank">
#             中文
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#        <div id="top-search">
#         <a href="#" id="top-search-trigger">
#          <i class="icon-search3">
#          </i>
#          <i class="icon-line-cross">
#          </i>
#         </a>
#         <form action="/search" method="get">
#          <input class="form-control" name="q" placeholder="search" type="text" value=""/>
#         </form>
#        </div>
#       </nav>
#      </div>
#     </div>
#    </header>
#    <section id="content">
#     <div class="content-wrap">
#      <div class="container clearfix">
#       <div class="center_wrapper">
#        <div class="row">
#         <div class="col-sm-12">
#          <div class="inbox_inspiration text-left">
#           <div class="row">
#            <div class="col-sm-4">
#             <h5>
#              Subscribe to our FREE
#              <br/>
#              inspirational quote emails!
#             </h5>
#             <form accept-charset="UTF-8" action="/users" class="simple_form new_user" id="new_user" method="post" novalidate="novalidate">
#              <input name="utf8" type="hidden" value="✓"/>
#              <input name="authenticity_token" type="hidden" value="hLQfCpDlbn4F1YHekMho3aIPR9+8wahhPLgxVuODRGr3CGQPv4KFwzZxtIgXKy/ZtOpquZTdlosi0TNQ+RgYnw=="/>
#              <div class="row">
#               <div class="col-sm-8">
#                <div class="input email optional user_email">
#                 <input class="string email optional sm-form-control sm-form-control-grey" id="user_email" name="user[email]" placeholder="Type your email address" style="height: 32px;" type="email"/>
#                </div>
#               </div>
#               <div class="col-sm-4">
#                <input class="btn btn btn-default btn-red noradius btn-hero" data-disable-with="Sending..." name="commit" type="submit" value="Subscribe"/>
#               </div>
#              </div>
#             </form>
#            </div>
#            <div class="col-sm-8">
#             <div class="row">
#              <div class="col-sm-4 bumper">
#               <div class="cycle-slideshow" data-cycle-fx="flipHorz" data-cycle-timeout="7000">
#                <img alt="20170116 monday quote" class="img-responsive" src="https://quotes.values.com/quote_artwork/3763/medium/20170116_monday_quote.jpg"/>
#                <img alt="Friday quote" class="img-responsive" src="https://quotes.values.com/quote_artwork/7347/medium/friday_quote.jpg"/>
#                <img alt="20170303 friday quote" class="img-responsive" src="https://quotes.values.com/quote_artwork/5014/medium/20170303_friday_quote.jpg"/>
#               </div>
#              </div>
#              <div class="col-sm-4 bumper">
#               <div class="cycle-slideshow" data-cycle-fx="flipHorz" data-cycle-timeout="6800">
#                <img alt="20161213 tuesday quote new" class="img-responsive" src="https://quotes.values.com/quote_artwork/7579/medium/20161213_tuesday_quote_new.jpg"/>
#                <img alt="Monday quote" class="img-responsive" src="https://quotes.values.com/quote_artwork/7313/medium/monday_quote.jpg"/>
#                <img alt="Friday quote" class="img-responsive" src="https://quotes.values.com/quote_artwork/7302/medium/friday_quote.jpg"/>
#               </div>
#              </div>
#              <div class="col-sm-4 bumper">
#               <div class="cycle-slideshow" data-cycle-fx="flipHorz" data-cycle-timeout="6600">
#                <img alt="20160906 tuesday quote" class="img-responsive" src="https://quotes.values.com/quote_artwork/6741/medium/20160906_tuesday_quote.jpg"/>
#                <img alt="Wednesday quote" class="img-responsive" src="https://quotes.values.com/quote_artwork/7280/medium/wednesday_quote.jpg"/>
#                <img alt="Tuesday quote" class="img-responsive" src="https://quotes.values.com/quote_artwork/7279/medium/tuesday_quote.jpg"/>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="row">
#         <div class="col-sm-6 col-sm-offset-3">
#          <form action="/inspirational-quotes" class="nobottommargin" id="" method="get" role="form">
#           <div class="input-group divcenter">
#            <input class="form-control" name="q" placeholder="Search quotes..." type="text"/>
#            <span class="input-group-btn">
#             <button class="btn btn-default" type="submit">
#              search
#             </button>
#            </span>
#           </div>
#          </form>
#          <hr/>
#         </div>
#        </div>
#       </div>
#       <div class="clear">
#       </div>
#       <div class="portfolio grid-container portfolio-4 portfolio-masonry clearfix" id="portfolio">
#        <article class="portfolio-item quotation true beauty">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/6943-i-think-your-whole-life-shows-in-your-face-and">
#           <img alt="I think your whole life shows in your face and you should be proud of that. #&lt;Author:0x007f6161960a90&gt;" class="hover" src="https://quotes.values.com/quote_artwork/6943/medium/20190215_friday_quote.jpg?1549567453"/>
#          </a>
#         </div>
#        </article>
#        <article class="portfolio-item quotation true beauty">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/6872-a-person-who-has-good-thoughts-cannot-ever-be">
#           <img alt="A person who has good thoughts cannot ever be ugly. You can have a wonky nose and a crooked mouth and a double chin and stick-out teeth, but if you have good thoughts they will shine out of your face like sunbeams and you will always look lovely. #&lt;Author:0x007f6162991fb8&gt;" class="hover" src="https://quotes.values.com/quote_artwork/6872/medium/20190214_thursday_quote.jpg?1549567422"/>
#          </a>
#         </div>
#        </article>
#        <article class="portfolio-item quotation true beauty">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/7873-true-beauty-does-not-shine-it-attracts">
#           <img alt="True beauty does not shine; it attracts. #&lt;Author:0x007f6160f60220&gt;" class="hover" src="https://quotes.values.com/quote_artwork/7873/medium/20190213_wednesday_quote.jpg?1549567389"/>
#          </a>
#         </div>
#        </article>
#        <article class="portfolio-item quotation true beauty">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/6807-to-be-beautiful-means-to-be-yourself-you-don-t">
#           <img alt="To be beautiful means to be yourself. You don’t need to be accepted by others. You need to accept yourself. #&lt;Author:0x007f6162d79770&gt;" class="hover" src="https://quotes.values.com/quote_artwork/6807/medium/20190212_tuesday_quote.jpg?1549567366"/>
#          </a>
#         </div>
#        </article>
#        <article class="portfolio-item quotation true beauty">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/7872-true-beauty-is-born-through-our-actions-and">
#           <img alt="True beauty is born through our actions and aspirations and in the kindness we offer to others. #&lt;Author:0x007f61630c6950&gt;" class="hover" src="https://quotes.values.com/quote_artwork/7872/medium/20190211_monday_quote_alternate2.jpg?1549646520"/>
#          </a>
#         </div>
#        </article>
#        <article class="portfolio-item quotation character">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/7032-i-have-a-dream-that-my-four-children-will-one">
#           <img alt="I have a dream that my four children will one day live in a nation where they will not be judged by the color of their skin, but by the content of their character. #&lt;Author:0x007f6162020ad8&gt;" class="hover" src="https://quotes.values.com/quote_artwork/7032/medium/20190208_friday_quote.jpg?1548806108"/>
#          </a>
#         </div>
#        </article>
#        <article class="portfolio-item quotation character">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/3230-every-experience-is-a-stitch-in-the-fabric-of">
#           <img alt="Every experience is a stitch in the fabric of your character. #&lt;Author:0x007f61617b8260&gt;" class="hover" src="https://quotes.values.com/quote_artwork/3230/medium/20190207_thursday_quote.jpg?1548806084"/>
#          </a>
#         </div>
#        </article>
#        <article class="portfolio-item quotation character">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/6745-the-greatest-discovery-of-our-generation-is">
#           <img alt="The greatest discovery of our generation is that human beings can alter their lives by altering their attitudes of mind. As you think, so shall you be. #&lt;Author:0x007f61618dc178&gt;" class="hover" src="https://quotes.values.com/quote_artwork/6745/medium/20190206_wednesday_quote.jpg?1548806062"/>
#          </a>
#         </div>
#        </article>
#        <article class="portfolio-item quotation character">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/6514-adversity-does-not-build-character-it-reveals-it">
#           <img alt="Adversity does not build character, it reveals it. #&lt;Author:0x007f61610558b0&gt;" class="hover" src="https://quotes.values.com/quote_artwork/6514/medium/20190205_tuesday_quote.jpg?1548806040"/>
#          </a>
#         </div>
#        </article>
#        <article class="portfolio-item quotation character">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/7871-if-i-take-care-of-my-character-my-reputation">
#           <img alt="If I take care of my character, my reputation will take care of itself. #&lt;Author:0x007f61614ed288&gt;" class="hover" src="https://quotes.values.com/quote_artwork/7871/medium/20190204_monday_quote.jpg?1548963744"/>
#          </a>
#         </div>
#        </article>
#        <article class="portfolio-item quotation appreciating nature">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/7870-i-go-to-nature-to-be-soothed-and-healed-and-to">
#           <img alt="I go to nature to be soothed and healed, and to have my senses put in order. #&lt;Author:0x007f6161929220&gt;" class="hover" src="https://quotes.values.com/quote_artwork/7870/medium/20190201_friday_quote.jpg?1548455490"/>
#          </a>
#         </div>
#        </article>
#        <article class="portfolio-item quotation appreciating nature">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/7869-and-into-the-forest-i-go-to-lose-my-mind-and">
#           <img alt="And into the forest I go, to lose my mind and find my soul. #&lt;Author:0x007f6161696a58&gt;" class="hover" src="https://quotes.values.com/quote_artwork/7869/medium/20190131_thursday_quote.jpg?1548455385"/>
#          </a>
#         </div>
#        </article>
#        <article class="portfolio-item quotation appreciating nature">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/7868-nature-is-not-matter-only-she-is-also-spirit">
#           <img alt="Nature is not matter only. She is also spirit. #&lt;Author:0x007f61617caa78&gt;" class="hover" src="https://quotes.values.com/quote_artwork/7868/medium/20190130_wednesday_quote.jpg?1548455344"/>
#          </a>
#         </div>
#        </article>
#        <article class="portfolio-item quotation appreciating nature">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/7508-i-felt-my-lungs-inflate-with-the-onrush-of">
#           <img alt="I felt my lungs inflate with the onrush of scenery—air, mountains, trees, people. I thought, ‘This is what it is to be happy.’ #&lt;Author:0x007f6162dc3ac8&gt;" class="hover" src="https://quotes.values.com/quote_artwork/7508/medium/20190129_tuesday_quote.jpg?1548455316"/>
#          </a>
#         </div>
#        </article>
#        <article class="portfolio-item quotation appreciating nature">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/7867-to-walk-into-nature-is-to-witness-a-thousand">
#           <img alt="To walk into nature is to witness a thousand miracles. #&lt;Author:0x007f6161b10a70&gt;" class="hover" src="https://quotes.values.com/quote_artwork/7867/medium/20190128_monday_quote.jpg?1548455282"/>
#          </a>
#         </div>
#        </article>
#        <article class="portfolio-item quotation equality">
#         <div class="portfolio-image">
#          <a href="/inspirational-quotes/7866-i-speak-not-for-myself-but-for-those-without">
#           <img alt="I speak not for myself but for those without voice… those who have fought for their rights… their right to live in peace, their right to be treated with dignity, their right to equality of opportunity, their right to be educated. #&lt;Author:0x007f61623f3660&gt;" class="hover" src="https://quotes.values.com/quote_artwork/7866/medium/20180125_friday_quote.jpg?1547859897"/>
#          </a>
#         </div>
#        </article>
#       </div>
#      </div>
#     </div>
#     <div class="center_wrapper">
#      <div class="pagination-centered" id="infinite-scrolling">
#       <ul class="pagination">
#        <li class="prev previous_page unavailable">
#         <a href="#">
#          «
#         </a>
#        </li>
#        <li class="current">
#         <a href="/inspirational-quotes?page=1">
#          1
#         </a>
#        </li>
#        <li>
#         <a href="/inspirational-quotes?page=2" rel="next">
#          2
#         </a>
#        </li>
#        <li>
#         <a href="/inspirational-quotes?page=3">
#          3
#         </a>
#        </li>
#        <li>
#         <a href="/inspirational-quotes?page=4">
#          4
#         </a>
#        </li>
#        <li>
#         <a href="/inspirational-quotes?page=5">
#          5
#         </a>
#        </li>
#        <li class="unavailable">
#         <a href="#">
#          <span class="gap">
#           …
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="/inspirational-quotes?page=222">
#          222
#         </a>
#        </li>
#        <li class="next next_page ">
#         <a href="/inspirational-quotes?page=2" rel="next">
#          »
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </section>
#    <footer class="dark" id="footer">
#     <div class="container clearfix">
#      <div class="row">
#       <div class="col-sm-3">
#        <ul class="footer_nav_links">
#         <li>
#          <a href="/inspirational-quotes">
#           Inspirational Quotations
#          </a>
#         </li>
#         <li>
#          <a href="/inspirational-stories-tv-spots">
#           Pass It On Videos
#          </a>
#         </li>
#         <li>
#          <a href="/inspirational-sayings-billboards">
#           Billboards
#          </a>
#         </li>
#         <li>
#          <a href="/radio">
#           Radio Ads
#          </a>
#         </li>
#         <li>
#          <a href="/inspirational-audio-stories">
#           Podcasts
#          </a>
#         </li>
#         <li>
#          <a href="/pass-it-on-ecards">
#           Ecards
#          </a>
#         </li>
#         <li>
#          <a href="/pass-it-on-downloads">
#           Downloads
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="col-sm-3">
#        <ul class="footer_nav_links">
#         <li>
#          <a href="/your-inspirational-stories">
#           Your Value Stories
#          </a>
#         </li>
#         <li>
#          <a href="/your-inspirational-stories/submit">
#           What Value Defines You?
#          </a>
#         </li>
#         <li>
#          <a href="/your-everyday-heroes">
#           Your Hero Stories
#          </a>
#         </li>
#         <li>
#          <a href="/your-everyday-heroes/submit">
#           Tell Us About Your Hero
#          </a>
#         </li>
#         <li>
#          <a href="/your-billboards">
#           Create Your Own Billboard
#          </a>
#         </li>
#         <li>
#          <a href="/users/subscribe">
#           Subscribe to Daily Quotes
#          </a>
#         </li>
#         <li>
#          <a href="/poster-requests/new">
#           Free Posters &amp; DVD for Schools
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="col-sm-3">
#        <ul class="footer_nav_links">
#         <li>
#          <a href="/who-we-are">
#           About Us
#          </a>
#         </li>
#         <li>
#          <a href="/who-we-are#faqs">
#           FAQs
#          </a>
#         </li>
#         <li>
#          <a href="/contact-us">
#           Contact Us
#          </a>
#         </li>
#         <li>
#          <a href="/who-we-are#awards">
#           Foundation Recognition
#          </a>
#         </li>
#         <li>
#          <a href="/who-we-are#media">
#           For Media Companies
#          </a>
#         </li>
#         <li>
#          <a href="/terms-of-use">
#           Terms of Use
#          </a>
#          &amp;
#          <a href="/privacy-policy">
#           Privacy Policy
#          </a>
#         </li>
#         <li style="color: #1a1a1a;">
#          en
#         </li>
#        </ul>
#        <div class="clearfix">
#        </div>
#       </div>
#       <div class="col-sm-3">
#        <a href="/">
#         <img alt="Passiton footer logo" height="26" src="/assets/passiton_footer_logo-096b4c04a71fdd79573aea3579388f88.png" style="margin-bottom: 20px;" width="200"/>
#        </a>
#        <br/>
#        <ul class="passiton-share-icons">
#         <li>
#          <a class="social-icon si-small si-rounded si-facebook" href="https://www.facebook.com/valuescom">
#           <i class="icon-facebook">
#           </i>
#          </a>
#         </li>
#         <li>
#          <a class="social-icon si-small si-rounded si-twitter" href="https://twitter.com/valuescom">
#           <i class="icon-twitter">
#           </i>
#          </a>
#         </li>
#         <li>
#          <a class="social-icon si-small si-rounded si-instagram" href="https://www.instagram.com/passiton_com/">
#           <i class="icon-instagram">
#           </i>
#          </a>
#         </li>
#         <li>
#          <a class="social-icon si-small si-rounded si-youtube" href="https://www.youtube.com/c/PassItOncom">
#           <i class="icon-youtube-play">
#           </i>
#          </a>
#         </li>
#         <li>
#          <a class="social-icon si-small si-rounded si-pinterest" href="https://www.pinterest.com/passiton/">
#           <i class="icon-pinterest">
#           </i>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#    </footer>
#   </div>
#   <div class="icon-angle-up" id="gotoTop">
#   </div>
#   <script src="/assets/application-739eb79af205cb6d65cef9be8c483acb.js">
#   </script>
#   <script integrity="sha384-EwBObn5QAxP8f09iemwAJljc+sU+eUXeL9vSBw1eNmVarwhKk2F9vBEpaN9rsrtp" src="//instant.page/1.1.0" type="module">
#   </script>
#  </body>
# </html>

# %%
from bs4 import BeautifulSoup
import requests
import re
import urllib
import os
import argparse
import sys
import json

# %%
def get_soup(url,header):
    return BeautifulSoup(urllib2.urlopen(urllib2.Request(url,headers=header)),'html.parser')

# %%
def main(args):
    parser = argparse.ArgumentParser(description='Scrape Google images')
    parser.add_argument('-s', '--search', default='bananas', type=str, help='search term')
    parser.add_argument('-n', '--num_images', default=10, type=int, help='num images to save')
    parser.add_argument('-d', '--directory', default='/Users/gene/Downloads/', type=str, help='save directory')
    args = parser.parse_args()
    query = args.search#raw_input(args.search)
    max_images = args.num_images
    save_directory = args.directory
    image_type="Action"
    query= query.split()
    query='+'.join(query)
    url="https://www.google.co.in/search?q="+query+"&source=lnms&tbm=isch"
    header={'User-Agent':"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.134 Safari/537.36"}
    soup = get_soup(url,header)
    ActualImages=[]# contains the link for Large original images, type of  image
    for a in soup.find_all("div",{"class":"rg_meta"}):
        link , Type =json.loads(a.text)["ou"]  ,json.loads(a.text)["ity"]
        ActualImages.append((link,Type))
    for i,(img , Type) in enumerate( ActualImages[0:max_images]):
        try:
            req = urllib2.Request(img, headers={'User-Agent' : header})
            raw_img = urllib2.urlopen(req).read()
            if len(Type)==0:
                f = open(os.path.join(save_directory , "img" + "_"+ str(i)+".jpg"), 'wb')
            else :
                f = open(os.path.join(save_directory , "img" + "_"+ str(i)+"."+Type), 'wb')
            f.write(raw_img)
            f.close()
        except Exception as e:
            print ("could not load : "+img)
            print (e)

# %%
from sys import argv
main(argv)
# Out:
# usage: ipykernel_launcher.py [-h] [-s SEARCH] [-n NUM_IMAGES] [-d DIRECTORY]
# ipykernel_launcher.py: error: unrecognized arguments: -f /run/user/1000/jupyter/kernel-b0b7d39b-1151-4a5d-8404-a561b060e159.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /home/sanchit/.local/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2971: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
